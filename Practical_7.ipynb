# %% [markdown]
# <a href="https://colab.research.google.com/github/teeshavaza10/hello/blob/main/Practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/indian_restaurants.csv")
print(data)
# Out:
#                             restaurant_name  rating  average_price  \
# 0                                    # Momo     4.2            200
# 1                                       #99     4.1            100
# 2                                      #BBQ     3.6            200
# 3                              #Dilliwaala6     3.7            100
# 4                                  #FlyFree     4.0            200
# ...                                     ...     ...            ...
# 27651               Shri Chau Mau Fast Food     3.8            150
# 27652                   Shri Chinese Center     2.8            150
# 27653                        Shri Dakshinam     3.9            100
# 27654  Shri Dashratna Veg Nonveg Restaurant     4.2            250
# 27655                Shri Devraj Bhojnalaya     3.1            150
#
#        average _delivery_time  south_indian_or_not  north_indian_or_not  \
# 0                          34                    0                    0
# ...

# %%
excel=pd.read_excel("/indian_restaurants.xlsx")
print(excel)
# Out:
#                             restaurant_name  rating  average_price  \
# 0                                    # Momo     4.2            200
# 1                                       #99     4.1            100
# 2                                      #BBQ     3.6            200
# 3                              #Dilliwaala6     3.7            100
# 4                                  #FlyFree     4.0            200
# ...                                     ...     ...            ...
# 27651               Shri Chau Mau Fast Food     3.8            150
# 27652                   Shri Chinese Center     2.8            150
# 27653                        Shri Dakshinam     3.9            100
# 27654  Shri Dashratna Veg Nonveg Restaurant     4.2            250
# 27655                Shri Devraj Bhojnalaya     3.1            150
#
#        average _delivery_time  south_indian_or_not  north_indian_or_not  \
# 0                          34                    0                    0
# ...

# %%
import matplotlib.image as nping
import matplotlib.pyplot as plt
img=nping.imread("/edinburgh.jpg")
plt.imshow(img)
